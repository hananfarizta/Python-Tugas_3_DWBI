# %% [markdown]
# <a href="https://colab.research.google.com/github/hananfarizta/Python-Tugas_3_DWBI/blob/main/Tugas_3_DWBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Get Data From Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv("/content/drive/MyDrive/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 652          5.0    123.0           74.0           40.0     77.0  34.1
# 283          7.0    161.0           86.0            0.0      0.0  30.4
# 441          2.0     83.0           66.0           23.0     50.0  32.2
# 503          7.0     94.0           64.0           25.0     79.0  33.3
# 238          9.0    164.0           84.0           21.0      0.0  30.8
# 450          1.0     82.0           64.0           13.0     95.0  21.2
# 579          2.0    197.0           70.0           99.0      0.0  34.7
# 321          3.0    112.0           74.0           30.0      0.0  31.6
# 287          1.0    119.0           86.0           39.0    220.0  45.6
# 373          2.0    105.0           58.0           40.0     94.0  34.9
#
#      DiabetesPedigreeFunction   Age  Outcome
# 652                     0.269  28.0        0
# 283                     0.165  47.0        1
# 441                     0.497  22.0        0
# 503                     0.738  41.0        0
# 238                     0.831  32.0        1
# 450                     0.415  23.0        0
# 579                     0.575  62.0        1
# 321                     0.197  25.0        1
# 287                     0.808  29.0        1
# 373                     0.225  25.0        0

# %%
#Number of rows and columns
df.shape
# Out:
# (768, 9)

# %%
#List the types of all columns
df.dtypes
# Out:
# Pregnancies                 float64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
#finding out if the dataset contains any null value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               763 non-null    float64
#  1   Glucose                   755 non-null    float64
#  2   BloodPressure             759 non-null    float64
#  3   SkinThickness             759 non-null    float64
#  4   Insulin                   757 non-null    float64
#  5   BMI                       764 non-null    float64
#  6   DiabetesPedigreeFunction  763 non-null    float64
#  7   Age                       767 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB

# %%
# Statistical summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   763.000000  755.000000     759.000000     759.000000  757.000000
# mean      3.846658  120.850331      69.208169      20.537549   79.911493
# std       3.371772   31.999297      19.276666      15.956681  115.648683
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      63.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   25.000000
# 75%       6.000000  140.500000      80.000000      32.000000  128.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  764.000000                763.000000  767.000000  768.000000
# mean    32.032723                  0.471523   33.252934    0.348958
# std      7.884334                  0.331498   11.763162    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.400000                  0.243500   24.000000    0.000000
# 50%     32.050000                  0.374000   29.000000    0.000000
# 75%     36.600000                  0.625000   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Drop the Duplicates check is there any duplicate rows are exist or not , if exist then we shold remove from the dataframe.

# %%
# check the shape before drop the duplicates
df.shape
# Out:
# (768, 9)

# %%
df = df.drop_duplicates()

# %%
# check the shape after drop the duplicates
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ### Check the NULL Value

# %%
# Display number of null values in every column in dataset
df.isnull().sum()
# Out:
# Pregnancies                  5
# Glucose                     13
# BloodPressure                9
# SkinThickness                9
# Insulin                     11
# BMI                          4
# DiabetesPedigreeFunction     5
# Age                          1
# Outcome                      0
# dtype: int64

# %%
df.mean()
# Out:
# Pregnancies                   3.846658
# Glucose                     120.850331
# BloodPressure                69.208169
# SkinThickness                20.537549
# Insulin                      79.911493
# BMI                          32.032723
# DiabetesPedigreeFunction      0.471523
# Age                          33.252934
# Outcome                       0.348958
# dtype: float64

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Add mean to NULL Value

# %%
df = df.fillna(df.mean())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.6
# 1            1.0     85.0           66.0           29.0      0.0  26.6
# 2            8.0    183.0           64.0            0.0      0.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            0.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      0.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            0.0      0.0  30.1
# 767          1.0     93.0           70.0           31.0      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# 1                       0.351  31.0        0
# 2                       0.672  32.0        1
# 3                       0.167  21.0        0
# 4                       2.288  33.0        1
# ..                        ...   ...      ...
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### Check the no. of zero values in dataset

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print('No. of zero values in Glucose ',df[df['Glucose']==0].shape[0])
# Out:
# No. of zero values in Glucose  5

# %%
print('No. of zero values in BloodPressure',df[df['BloodPressure']==0].shape[0])
# Out:
# No. of zero values in BloodPressure 34

# %%
print('No. of zero values in SkinThickness ',df[df[ 'SkinThickness' ]==0].shape[0])
# Out:
# No. of zero values in SkinThickness  224

# %%
print('No. of zero values in Insulin',df[df[ 'Insulin']==0].shape[0])
# Out:
# No. of zero values in Insulin 370

# %%
print('No. of zero values in BMI',df[df['BMI']==0].shape[0])
# Out:
# No. of zero values in BMI 11

# %% [markdown]
# ### Replace no.of zero values with mean of that columns

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df[ 'BloodPressure']=df[ 'BloodPressure' ].replace(0,df['BloodPressure' ].mean())
df[ 'SkinThickness']=df[ 'SkinThickness' ].replace(0,df[ 'SkinThickness'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin' ].mean())

df['BMI']=df[ 'BMI' ].replace(0,df['BMI'].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.846658  121.637117      72.272072      26.527668  118.410519
# std       3.360764   30.179011      12.062598       9.618573   92.834106
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000  100.000000      64.000000      20.537549   79.911493
# 50%       3.000000  118.000000      72.000000      23.000000   79.911493
# 75%       6.000000  140.000000      80.000000      32.000000  126.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.491525                  0.471523   33.252934    0.348958
# std      6.849228                  0.330416   11.755491    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.600000                  0.244000   24.000000    0.000000
# 50%     32.032723                  0.377000   29.000000    0.000000
# 75%     36.600000                  0.620250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Count plot

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))

df[ 'Outcome'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')

sns.countplot('Outcome',data=df,ax=ax[1])
ax[1].set_title('Outcome')

N,P = df['Outcome'].value_counts()
print('Negative (0):',N)

print( 'Positive (1): ',P)

plt.grid()

plt. show()
# Out:
# Negative (0): 500
# Positive (1):  268

# %% [markdown]
# Out of 768 people, 268 are diabetic (positive(1)) and 500 are non-diabetic (negative(0)).
#
# In the outcome column, 1 represents diabetes positive & 0 represents diabetes negative
#
# The counterplot tells us that the dataset is imbalanced, as number of patients who dont have diabetes is more than those who have diabetes

# %% [markdown]
# ### Histograms

# %%
df .hist (bins=10, figsize=(10,10))
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20, 20));

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data = df, hue = 'Outcome')
plt.show()

# %% [markdown]
# ### Correlation analysis

# %%
import seaborn as sns

#get correlations of each features in dataset

corrmat = df.corr()

top_corr_features = corrmat.index

plt.figure(figsize=(10,10))

#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# Observations:
#
# From the correaltion heatmap, we can see that there is a high correlation between Outcome and [Pregnancies,Glucose,BMI,Age,Insulin]. We can select these features to accept input from the user and predict the outcome.

# %% [markdown]
# ### Split the data frame into X & y

# %%
target_name = 'Outcome'

# Separate object for target feature
y = df[target_name]

# Separate Object for Input Features
X = df.drop(target_name, axis=1)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0          6.0    148.0           72.0      35.000000   79.911493  33.6
# 1          1.0     85.0           66.0      29.000000   79.911493  26.6
# 2          8.0    183.0           64.0      20.537549   79.911493  23.3
# 3          1.0     89.0           66.0      23.000000   94.000000  28.1
# 4          0.0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Apply Feature Scaling

# %%
# Apply Standard Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler. fit(X)

SSX = scaler. transform(X)

# %% [markdown]
# Inplace of Standard Sclaer you have to try other data scaling techniques like normalizer, minmax scaler and binarizer

# %% [markdown]
# ### TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# ## Build the CLASSIFICATION Algorithms

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear' ,multi_class='ovr')
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt. fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='entropy')
rf.fit(X_train,y_train)

RandomForestClassifier(criterion='entropy')
# Out:
# RandomForestClassifier(criterion='entropy')

# %% [markdown]
# ## Making Prediction

# %%
## Making predictions on test dataset
lr_pred=lr.predict(X_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %% [markdown]
# ### Decesion Tree

# %%
#Making predictions on test dataset
dt_pred=dt.predict(X_test)
dt_pred.shape
# Out:
# (154,)

# %% [markdown]
# ### Random Forest

# %%
#Making predictions on test dataset
rf_pred=rf.predict(X_test)
rf_pred.shape
# Out:
# (154,)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Train Score & Test Score

# %%
# Train score & Test score of Logistic Regression
from sklearn.metrics import accuracy_score

print("Train Accuracy of Logistic Regression",lr.score(X_train, y_train)*100)
print("Accuracy (Test) score of Logistic Regression",lr.score(X_test, y_test)*100)
print("Accuracy (Test) score of Logistic Regression" ,accuracy_score(y_test,lr_pred)*100)
# Out:
# Train Accuracy of Logistic Regression 77.52442996742671
# Accuracy (Test) score of Logistic Regression 75.97402597402598
# Accuracy (Test) score of Logistic Regression 75.97402597402598

# %%
# Train score & Test score of Decesion Tree

print("Train Accuracy of Decesion Tree", dt.score(X_train,y_train)*100)
print("Accuracy (Test) score of Decesion Tree",dt.score(X_test, y_test)*100)
print("Accuracy score of Decesion Tree",accuracy_score(y_test,dt_pred)*100)
# Out:
# Train Accuracy of Decesion Tree 100.0
# Accuracy (Test) score of Decesion Tree 75.97402597402598
# Accuracy score of Decesion Tree 75.97402597402598

# %%
# Train score & Test score of Random Forest

print("Train Accuracy of Random Forest",rf.score(X_train,y_train)*100)
print("Accuracy (Test) score of Random Forest", rf.score(X_test, y_test)*100)
print("Accuracy score of Random Forest",accuracy_score(y_test,rf_pred)*100)
# Out:
# Train Accuracy of Random Forest 100.0
# Accuracy (Test) score of Random Forest 77.92207792207793
# Accuracy score of Random Forest 77.92207792207793

# %% [markdown]
# Confusion Matrix
#
# Confusion metrics is a table which is used to describe the performance of a classification problem.
#
# It visualizes the accuracy of a classifier by comparing predicted values with actual values.
#
# The terms used in confusion metrics are True positive (TP), true negative (TN), false positive (FP) and false negative (FN) True Positive: The predicted result is positive, while it is labeled as positive.
#
# False Positive: The predicted result is positive, while it is labeled as negative. It calls Type | Error as well.
#
# False Negative: The predicted result is negative, while it is labeled as positive, It calls Type II Error as well.
#
# True Negative: The predicted result is negative, while it is labeled as negative.

# %% [markdown]
# ### Confusion Matrix of “Logistic Regression”

# %%
from sklearn.metrics import classification_report,confusion_matrix
# confusion Matrix of Logistic Regression

cm=confusion_matrix(y_test,lr_pred)
cm
# Out:
# array([[85, 12],
#        [25, 32]])

# %%
sns.heatmap(confusion_matrix(y_test,lr_pred),annot=True, fmt="d")

# %%
print('Classification Report of Logistic Regression: \n',classification_report(y_test,lr_pred,digits=4))

TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]
TP = cm[1,1]

TN, FP, FN, TP
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0     0.7727    0.8763    0.8213        97
#            1     0.7273    0.5614    0.6337        57
#
#     accuracy                         0.7597       154
#    macro avg     0.7500    0.7188    0.7275       154
# weighted avg     0.7559    0.7597    0.7518       154
# (85, 12, 25, 32)

# %%
# Making the Confusion Matrix OF Logistic Regression

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, lr_pred)

print('TN - True Negative {}'.format(cm[0,0]))

print('FP - False Positive {}'.format(cm[0,1]))

print('FN - False Negative {}'.format(cm[1,0]))
print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))*100))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN - True Negative 85
# FP - False Positive 12
# FN - False Negative 25
# TP - True Positive 32
# Accuracy Rate: 75.97402597402598
# Misclassification Rate: 24.025974025974026

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Wistia)
classNames = ['0','1']
plt.title( 'Confusion Matrix OF Logistic Regression')
plt.ylabel('Actual(true) values')
plt.xlabel( 'Predicted values')
tick_marks = np.arange(len(classNames))
plt.xticks(tick_marks, classNames, rotation=45)
plt.yticks(tick_marks, classNames)
s = [['TN','FP'], ['FN', 'TP']]
for i in range(2):
    for j in range(2):
        plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))

# %%
# Making the Confusion Matrix OF Decision Tree

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
cm = confusion_matrix(y_test, dt_pred)

print('TN - True Negative {}'.format(cm[0,0]))

print('FP - False Positive {}'.format(cm[0,1]))

print('FN - False Negative {}'.format(cm[1,0]))

print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))
# Out:
# TN - True Negative 76
# FP - False Positive 21
# FN - False Negative 16
# TP - True Positive 41
# Accuracy Rate: 0.7597402597402597
# Misclassification Rate: 0.24025974025974026

# %%
print('Classification Report of DI: \n', classification_report(y_test,dt_pred,digits=4))
# Out:
# Classification Report of DI:
#                precision    recall  f1-score   support
#
#            0     0.8261    0.7835    0.8042        97
#            1     0.6613    0.7193    0.6891        57
#
#     accuracy                         0.7597       154
#    macro avg     0.7437    0.7514    0.7467       154
# weighted avg     0.7651    0.7597    0.7616       154

# %%
# Making the Confusion Matrix OF Random Forest
cm = confusion_matrix(y_test, rf_pred)

print('TN - True Negative {}'.format(cm[0,0]))

print('FP - False Positive {}'.format(cm[0,1]))

print('FN - False Negative {}'.format(cm[1,0]))

print('TP - True Positive {}'.format(cm[1,1]))

print('Accuracy Rate: {}'.format(np.divide(np.sum([cm[0,0],cm[1,1]]),np.sum(cm))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))))
# Out:
# TN - True Negative 85
# FP - False Positive 12
# FN - False Negative 22
# TP - True Positive 35
# Accuracy Rate: 0.7792207792207793
# Misclassification Rate: 0.22077922077922077

# %%
print('Classification Report of RF: \n', classification_report(y_test,rf_pred,digits=4))
# Out:
# Classification Report of RF:
#                precision    recall  f1-score   support
#
#            0     0.7944    0.8763    0.8333        97
#            1     0.7447    0.6140    0.6731        57
#
#     accuracy                         0.7792       154
#    macro avg     0.7695    0.7452    0.7532       154
# weighted avg     0.7760    0.7792    0.7740       154
